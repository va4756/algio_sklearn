# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/algio_sklearn/blob/main/bigdata_sinagong_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter Notebook에서 /Google 드라이브/2025_시나공_빅데이터분석기사_실기_데이터파일/ -> 에 있음

# %% [markdown]
# # ch2_pandas

# %% [markdown]
# ## 판다스

# %% [markdown]
# ### Section1. 데이터프레임과 시리즈

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# %%
# 시리즈 만들기 (문자열)
menu = pd.Series(['짜장면', '짬뽕', '탕수육'])
menu
# Out:
# 0    짜장면
# 1     짬뽕
# 2    탕수육
# dtype: object

# %%
# 시리즈 만들기(정수형)
price = pd.Series([4000, 5000, 6000])
price
# Out:
# 0    4000
# 1    5000
# 2    6000
# dtype: int64

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
pd.DataFrame({'menu': menu,
              'price': price})
# Out:
#   menu  price
# 0  짜장면   4000
# 1   짬뽕   5000
# 2  탕수육   6000

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
df = pd.DataFrame({
    'menu': ['짜장면', '짬뽕', '탕수육'],
    'price': [4000, 5000, 6000],
    'category': ['중식', '중식', '한식']
})
df
# Out:
#   menu  price category
# 0  짜장면   4000       중식
# 1   짬뽕   5000       중식
# 2  탕수육   6000       한식

# %%
# 시리즈 선택 (가격)
df['price']
# Out:
# 0    4000
# 1    5000
# 2    6000
# Name: price, dtype: int64

# %%
# 데이터프레임 선택 (가격)
df[['price']]
# Out:
#    price
# 0   4000
# 1   5000
# 2   6000

# %%
df[['menu', 'price']]
# Out:
#   menu  price
# 0  짜장면   4000
# 1   짬뽕   5000
# 2  탕수육   6000

# %%
# 데이터프레임 선택 (가격)
cols = ['menu', 'price']
df[cols]
# Out:
#   menu  price
# 0  짜장면   4000
# 1   짬뽕   5000
# 2  탕수육   6000

# %%
# 데이터 프레임 type 확인
print("df          : ", type(df))
print("df['가격']   : ", type(df['price']))
print("df[['가격']] : ", type(df[['price']]))
# Out:
# df          :  <class 'pandas.core.frame.DataFrame'>
# df['가격']   :  <class 'pandas.core.series.Series'>
# df[['가격']] :  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Section2. 데이터 저장 및 불러오기

# %%
# 데이터 준비
df = pd.DataFrame({
    "메뉴":['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
    "가격":[4500, 5000, 5500, 5000, 4000, 5900, 5300],
    "칼로리":[10, 110, 250, 110, 20, 210, 0],
})
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.to_csv('temp.csv')

# %%
temp_df = pd.read_csv('temp.csv', index_col=0)
temp_df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
# 데이터 불러오기
df.to_csv('cafe.csv', index=False)
df = pd.read_csv('cafe.csv')
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %% [markdown]
# ### Section3. 탐색적 데이터 분석(EDA)

# %%
# 데이터 샘플 확인: 앞에서 부터 n개 (기본 5개)
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
# 데이터 샘플 확인: 뒤에서 부터 n개 (기본 5개)
df.tail(3)
# Out:
#       메뉴    가격  칼로리
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.sample(3)
# Out:
#      메뉴    가격  칼로리
# 6    녹차  5300    0
# 3  카푸치노  5000  110
# 1  카페라떼  5000  110

# %%
# 데이터 프레임 크기 (행, 컬럼)
df.shape
# Out:
# (7, 3)

# %%
# 컬럼 형태(type)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
# 상관관계
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.713227
# 칼로리  0.713227  1.000000

# %%
# 중복 값이 있는 데이터 생성
df_car = pd.DataFrame({
    "car":['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
    "size":['S','M','S','S','M','M','L','S','S', 'M','S']
})
df_car.head(3)
# Out:
#      car size
# 0  Sedan    S
# 1    SUV    M
# 2  Sedan    S

# %%
# 항목 종류 수
df_car.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
# 항목 종류
print(df_car['car'].unique())
print(df_car['size'].unique())
# Out:
# ['Sedan' 'SUV']
# ['S' 'M' 'L']

# %%
# 항목별 개수
print(df_car['car'].value_counts())
print(df_car['size'].value_counts())
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64
# size
# S    6
# M    4
# L    1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 가격         칼로리
# count     7.000000    7.000000
# mean   5028.571429  101.428571
# std     631.702160   99.402980
# min    4000.000000    0.000000
# 25%    4750.000000   15.000000
# 50%    5000.000000  110.000000
# 75%    5400.000000  160.000000
# max    5900.000000  250.000000

# %%
df_car.describe(include='object')
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df.describe(include='object')
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %% [markdown]
# ### Section4. 자료형 변환

# %%
data = {
    "메뉴":['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
    "가격":[4500.0, 5000.0, 5500.0, 5000.0, 4000.0, 5900.0, 5300.0],
    "칼로리":['10', '110', '250', '110', '20', '210', '0'],
}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      float64
#  2   칼로리     7 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df.shape
# Out:
# (7, 3)

# %%
df['가격'] = df['가격'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['칼로리'] = df['칼로리'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.0+ bytes

# %% [markdown]
# ### Section5. 새로운 컬럼 추가

# %%
df = pd.read_csv('cafe.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
# 새로운 컬럼 추가 (값은 0)
df['new'] = 0
df.head(2)
# Out:
#       메뉴    가격  칼로리  new
# 0  아메리카노  4500   10    0
# 1   카페라떼  5000  110    0

# %%
# 할인가 컬럼 추가
discount = 0.2
df['할인가'] = df['가격'] * (1 - discount)
df.head(2)
# Out:
#       메뉴    가격  칼로리  new     할인가
# 0  아메리카노  4500   10    0  3600.0
# 1   카페라떼  5000  110    0  4000.0

# %% [markdown]
# ### Section6. 데이터 삭제 (컬럼, 행)

# %%
df = pd.read_csv('cafe.csv')
df.head(3)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250

# %% [markdown]
# #### 행 삭제

# %%
# 행 삭제
df.drop(1, axis=0, inplace=True)
df.head(3)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 2   카페모카  5500  250
# 3   카푸치노  5000  110

# %% [markdown]
# #### 컬럼 삭제

# %%
# 데이터 삭제
# axis=0:행방향, axis=1:열방향(컬럼)
df = df.drop('칼로리', axis=1)
df.head(3)
# Out:
#       메뉴    가격
# 0  아메리카노  4500
# 2   카페모카  5500
# 3   카푸치노  5000

# %% [markdown]
# ### Section7. 인덱싱/슬라이싱(loc)

# %% [markdown]
# #### (인덱스 명), (인덱스 명(범위), 컬럼 명(범위))

# %%
# 데이터 불러오기
import pandas as pd
df = pd.read_csv('cafe.csv')
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
# 인덱싱 (행 전체)
# 아메리카노
df.loc[0]
# Out:
# 메뉴     아메리카노
# 가격      4500
# 칼로리       10
# Name: 0, dtype: object

# %%
# 카페라떼 가격
df.loc[1, '가격']
# Out:
# 5000

# %%
# 슬라이싱 (컬럼 전체)
# 가격
df.loc[:, '가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
# 슬라이싱
df.loc[2, '메뉴':'칼로리']
# Out:
# 메뉴     카페모카
# 가격     5500
# 칼로리     250
# Name: 2, dtype: object

# %%
# 슬라이싱
# 카페모카 메뉴와 칼로리
df.loc[2, ['메뉴', '칼로리']]
# Out:
# 메뉴     카페모카
# 칼로리     250
# Name: 2, dtype: object

# %%
# 슬라이싱
df.loc[1:3, '메뉴':'가격']
# Out:
#      메뉴    가격
# 1  카페라떼  5000
# 2  카페모카  5500
# 3  카푸치노  5000

# %% [markdown]
# ### Section8. 인덱싱/슬라이싱(iloc)

# %% [markdown]
# #### (인덱스 번호), (인덱스 번호(범위), 컬럼 번호(범위))

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df.drop(0, axis=0, inplace=True)   # 첫번째 행 삭제
df.head()
# Out:
#       메뉴    가격  칼로리
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210

# %%
# 인덱싱 (행 전체)
# 카페라떼
df.iloc[0]
# Out:
# 메뉴     카페라떼
# 가격     5000
# 칼로리     110
# Name: 1, dtype: object

# %%
# 슬라이싱 (컬럼 전체)
# 가격
df.iloc[:, 1]
# Out:
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
# 슬라이싱
# 카페모카 메뉴와 가격
df.iloc[2, 0:2]
# Out:
# 메뉴    카푸치노
# 가격    5000
# Name: 3, dtype: object

# %%
# 슬라이싱 (카페라떼와 카페모카의 전체 데이터)
df.iloc[1:3]
# Out:
#      메뉴    가격  칼로리
# 2  카페모카  5500  250
# 3  카푸치노  5000  110

# %%
df.loc[2:3, '메뉴':'칼로리']
# Out:
#      메뉴    가격  칼로리
# 2  카페모카  5500  250
# 3  카푸치노  5000  110

# %% [markdown]
# ### Section9. 데이터 추가/변경

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
# 결측값으로 추가, 원두 컬럼을 만들고 결측값(NaN)으로 대입
import numpy as np
df['원산지'] = np.nan
df.head()
# Out:
#       메뉴    가격  칼로리  원산지
# 0  아메리카노  4500   10  NaN
# 1   카페라떼  5000  110  NaN
# 2   카페모카  5500  250  NaN
# 3   카푸치노  5000  110  NaN
# 4  에스프레소  4000   20  NaN

# %%
# 아메리카노의 원두는 '콜롬비아' 데이터 추가
df.loc[0, '원산지'] = '콜롬비아'
df.loc[2:3, '원산지'] = '과테말라'
df.head()
# Out:
# <ipython-input-53-55b3629810d6>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '콜롬비아' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0, '원산지'] = '콜롬비아'
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
# 리스트 형태로 데이터(행) 추가
df.loc['시즌'] = ['크리스마스라떼', 6000, 300, '한국']
df.tail()
# Out:
#          메뉴    가격  칼로리   원산지
# 3      카푸치노  5000  110  과테말라
# 4     에스프레소  4000   20   NaN
# 5       밀크티  5900  210   NaN
# 6        녹차  5300    0   NaN
# 시즌  크리스마스라떼  6000  300    한국

# %%
# 딕셔너리 형태로 데이터(행) 추가
df.loc[7] = {'메뉴':'딴짓커피', '가격':2000, '칼로리':20}
df.tail()
# Out:
#          메뉴    가격  칼로리  원산지
# 4     에스프레소  4000   20  NaN
# 5       밀크티  5900  210  NaN
# 6        녹차  5300    0  NaN
# 시즌  크리스마스라떼  6000  300   한국
# 7      딴짓커피  2000   20  NaN

# %%
df.drop('시즌', axis=0, inplace=True)
df.to_csv('cafe2.csv', index=False)

# %% [markdown]
# ### Section10. 정렬

# %%
# 데이터 불러오기
df = pd.read_csv('cafe2.csv')
df.head()
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
# 인덱스 기준 (기본값 ascending=True)
df.sort_index(ascending=False)
# Out:
#       메뉴    가격  칼로리   원산지
# 7   딴짓커피  2000   20   NaN
# 6     녹차  5300    0   NaN
# 5    밀크티  5900  210   NaN
# 4  에스프레소  4000   20   NaN
# 3   카푸치노  5000  110  과테말라
# 2   카페모카  5500  250  과테말라
# 1   카페라떼  5000  110   NaN
# 0  아메리카노  4500   10  콜롬비아

# %%
# 값 기준 (기본값 ascending=True)
# 메뉴 기준 정렬
df.sort_values(by='메뉴', ascending=False)
# Out:
#       메뉴    가격  칼로리   원산지
# 3   카푸치노  5000  110  과테말라
# 2   카페모카  5500  250  과테말라
# 1   카페라떼  5000  110   NaN
# 4  에스프레소  4000   20   NaN
# 0  아메리카노  4500   10  콜롬비아
# 5    밀크티  5900  210   NaN
# 7   딴짓커피  2000   20   NaN
# 6     녹차  5300    0   NaN

# %%
# 가격과 메뉴 기준 정렬
df.sort_values(by=['가격', '메뉴'], ascending=[False, True], inplace=True)
df
# Out:
#       메뉴    가격  칼로리   원산지
# 5    밀크티  5900  210   NaN
# 2   카페모카  5500  250  과테말라
# 6     녹차  5300    0   NaN
# 1   카페라떼  5000  110   NaN
# 3   카푸치노  5000  110  과테말라
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 7   딴짓커피  2000   20   NaN

# %%
# 인덱스 새로 만들기 drop=True
df.reset_index(drop=True)
# Out:
#       메뉴    가격  칼로리   원산지
# 0    밀크티  5900  210   NaN
# 1   카페모카  5500  250  과테말라
# 2     녹차  5300    0   NaN
# 3   카페라떼  5000  110   NaN
# 4   카푸치노  5000  110  과테말라
# 5  아메리카노  4500   10  콜롬비아
# 6  에스프레소  4000   20   NaN
# 7   딴짓커피  2000   20   NaN

# %% [markdown]
# ### Section11. 필터링

# %%
# 데이터 불러오기
df = pd.read_csv('cafe2.csv')
df.head()
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
df['칼로리'] < 50
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# Name: 칼로리, dtype: bool

# %%
# 1개 조건
cond = df['칼로리'] < 50
df[cond]
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
# 1개 조건
df[df['칼로리'] < 50]
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
cond = df['칼로리'] < 50
df[~cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
# 2개 이상 일때 (AND)
cond1 = df['가격'] >= 5000
cond2 = df['칼로리'] > 100
df[cond1 & cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
# 2개 이상 일때 (OR)
df[cond1 | cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN
# 6    녹차  5300    0   NaN

# %%
# 문자열 1개 조건
# 원두 == 콜롬비아
cond = (df['원산지'] == '과테말라')
df[cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라

# %%
# 문자열과 숫자 조건 (AND)
cond1 = df['원산지'] == '과테말라'
cond2 = df['가격'] <= 5000
df[cond1 & cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 3  카푸치노  5000  110  과테말라

# %%
df['메뉴'].isin(['녹차'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# Name: 메뉴, dtype: bool

# %%
cond = df['메뉴'].isin(['녹차'])
df[cond]
# Out:
#    메뉴    가격  칼로리  원산지
# 6  녹차  5300    0  NaN

# %%
box = ['녹차', '카푸치노', '카페라떼']
cond = df['메뉴'].isin(box)
df[cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 3  카푸치노  5000  110  과테말라
# 6    녹차  5300    0   NaN

# %% [markdown]
# ### Section12. 결측치 처리

# %%
# 데이터 불러오기
df = pd.read_csv('cafe2.csv')
df.head()
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
df.isnull()
# Out:
#       메뉴     가격    칼로리    원산지
# 0  False  False  False  False
# 1  False  False  False   True
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False   True
# 5  False  False  False   True
# 6  False  False  False   True
# 7  False  False  False   True

# %%
# 컬럼별 결측치 확인
df.isnull().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    5
# dtype: int64

# %%
# 컬럼별 결측치 확인
df.isna().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    5
# dtype: int64

# %%
# 결측값 채우기
df['원산지'].fillna('코스타리카', inplace=True)
df
# Out:
# <ipython-input-78-a81a900a4380>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['원산지'].fillna('코스타리카', inplace=True)
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
df.to_csv('cafe3.csv', index=False)

# %% [markdown]
# ### Section13. 값 변경

# %%
# 데이터 확인
df = pd.read_csv('cafe3.csv')
df.head()
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카

# %%
# 문자 변경 : 아메리카노 -> 룽고, 녹차 -> 그린티
df.replace('아메리카노', '룽고', inplace=True)
df.replace('녹차', '그린티', inplace=True)
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0     룽고  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6    그린티  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
change = {'룽고':'아메리카노', '그린티':'녹차'}
df.replace(change, inplace=True)
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
# loc로 값 변경하기
df.loc[6, '원산지'] = '대한민국'
df.tail()
# Out:
#       메뉴    가격  칼로리    원산지
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0   대한민국
# 7   딴짓커피  2000   20  코스타리카

# %%
# 이벤트가 전체 1000으로 변경
df.loc[1:2, '이벤트가'] = 1000
df.head()
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN

# %%
df.to_csv('cafe4.csv', index=False)

# %% [markdown]
# ### Section14. 문자열

# %%
import pandas as pd
df = pd.DataFrame({
    'A': ['데이터 분석', '기본 학습서', '퇴근 후 열공'],
    'B': [10, 20, 30],
    'C': ['ab cd', 'AB CD', 'ab cd ']
})
df
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['A'] = df['A'].replace('분석', '시각화')
df
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['A'] = df['A'].str.replace('분석', '시각화')
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['B'] = df['B'].replace(10, 100)
df
# Out:
#          A    B       C
# 0  데이터 시각화  100   ab cd
# 1   기본 학습서   20   AB CD
# 2  퇴근 후 열공   30  ab cd

# %%
# 문자열 분리
df['A'].str.split()
# Out:
# 0     [데이터, 시각화]
# 1      [기본, 학습서]
# 2    [퇴근, 후, 열공]
# Name: A, dtype: object

# %%
df['A'].str.split()[0]
# Out:
# ['데이터', '시각화']

# %%
df['D'] = df['A'].str.split().str[0]
df
# Out:
#          A    B       C    D
# 0  데이터 시각화  100   ab cd  데이터
# 1   기본 학습서   20   AB CD   기본
# 2  퇴근 후 열공   30  ab cd    퇴근

# %%
# 문자 검색
df['A'].str.contains('기본')
# Out:
# 0    False
# 1     True
# 2    False
# Name: A, dtype: bool

# %%
df['기본포함유무'] = df['A'].str.contains('기본')
df
# Out:
#          A    B       C    D  기본포함유무
# 0  데이터 시각화  100   ab cd  데이터   False
# 1   기본 학습서   20   AB CD   기본    True
# 2  퇴근 후 열공   30  ab cd    퇴근   False

# %%
menu = pd.Series(['맛난버거 세트', '매운 치킨버거', '더블 치즈버거'])
menu.isin(['맛난버거 세트', '더블 치즈버거'])
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
menu.str.contains('세트')
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
df['문자길이'] = df['A'].str.len()
df
# Out:
#          A    B       C    D  기본포함유무  문자길이
# 0  데이터 시각화  100   ab cd  데이터   False     7
# 1   기본 학습서   20   AB CD   기본    True     6
# 2  퇴근 후 열공   30  ab cd    퇴근   False     7

# %%
'AB cd' == 'ab CD'
# Out:
# False

# %%
df['C'] = df['C'].str.lower()
df['C']
# Out:
# 0     ab cd
# 1     ab cd
# 2    ab cd
# Name: C, dtype: object

# %%
df['C'] = df['C'].str.upper()
df['C']
# Out:
# 0     AB CD
# 1     AB CD
# 2    AB CD
# Name: C, dtype: object

# %%
df['C'] == 'AB CD'
# Out:
# 0     True
# 1     True
# 2    False
# Name: C, dtype: bool

# %%
df['C'] = df['C'].str.lower()
df['C'] = df['C'].str.replace(" ", "")
df['C']
# Out:
# 0    abcd
# 1    abcd
# 2    abcd
# Name: C, dtype: object

# %%
df['C'].str[1:3]
# Out:
# 0    bc
# 1    bc
# 2    bc
# Name: C, dtype: object

# %%
df['C'][1:3]
# Out:
# 1    abcd
# 2    abcd
# Name: C, dtype: object

# %% [markdown]
# ### Section15. 내장함수

# %% [markdown]
# #### 데이터 핸들링을 위한 판다스 기초1(EDA) 부분에서 일부 내장함수를 학습했고, 그외 함수에 대해 살펴봄

# %%
df = pd.read_csv('cafe4.csv')
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
print(len(df))
print(df.shape[0])
# Out:
# 8
# 8

# %%
cond = df['가격'] > 5000

#sum으로 조건에 맞는 개수 구하기
print(sum(cond))

#len으로 조건에 맞는 개수 구하기
print(len(df[cond]))
# Out:
# 3
# 3

# %%
df.sum(numeric_only=True)
# Out:
# 가격      37200.0
# 칼로리       730.0
# 이벤트가     2000.0
# dtype: float64

# %%
df.sum(axis=1, numeric_only=True)
# Out:
# 0    4510.0
# 1    6110.0
# 2    6750.0
# 3    5110.0
# 4    4020.0
# 5    6110.0
# 6    5300.0
# 7    2020.0
# dtype: float64

# %%
print("최대값: ",df['가격'].max())
print("최소값: ",df['가격'].min())
print("평균값: ",df['가격'].mean())
print("중앙값: ",df['가격'].median())
print("합계: ",df['가격'].sum())
print("표준편차: ",df['가격'].std())
print("분산: ",df['가격'].var())
# Out:
# 최대값:  5900
# 최소값:  2000
# 평균값:  4650.0
# 중앙값:  5000.0
# 합계:  37200
# 표준편차:  1220.070255588353
# 분산:  1488571.4285714286

# %%
# 분위수
print('분위수 25% 값:', df['가격'].quantile(0.25))
print('분위수 75% 값:', df['가격'].quantile(0.75))
# Out:
# 분위수 25% 값: 4375.0
# 분위수 75% 값: 5350.0

# %%
# 하위 25% 데이터
cond = df['가격'].quantile(0.25) > df['가격']
df[cond]
# Out:
#       메뉴    가격  칼로리    원산지  이벤트가
# 4  에스프레소  4000   20  코스타리카   NaN
# 7   딴짓커피  2000   20  코스타리카   NaN

# %%
# 상위 25% 데이터
cond = df['가격'].quantile(0.75) < df['가격']
df[cond]
# Out:
#      메뉴    가격  칼로리    원산지    이벤트가
# 2  카페모카  5500  250   과테말라  1000.0
# 5   밀크티  5900  210  코스타리카     NaN

# %%
# 최빈값 구하기
df['원산지'].mode()[0]
# Out:
# '코스타리카'

# %%
df['가격'].idxmax()
# Out:
# 5

# %%
max_ind = df['가격'].idxmax()
df.loc[max_ind]
# Out:
# 메뉴        밀크티
# 가격       5900
# 칼로리       210
# 원산지     코스타리카
# 이벤트가      NaN
# Name: 5, dtype: object

# %%
df.loc[max_ind]['메뉴']
# Out:
# '밀크티'

# %%
df.nlargest(3, '가격')
# Out:
#      메뉴    가격  칼로리    원산지    이벤트가
# 5   밀크티  5900  210  코스타리카     NaN
# 2  카페모카  5500  250   과테말라  1000.0
# 6    녹차  5300    0   대한민국     NaN

# %%
df.nsmallest(3, '가격')
# Out:
#       메뉴    가격  칼로리    원산지  이벤트가
# 7   딴짓커피  2000   20  코스타리카   NaN
# 4  에스프레소  4000   20  코스타리카   NaN
# 0  아메리카노  4500   10   콜롬비아   NaN

# %%
# apply 적용해서 새로운 컬럼 생성 (칼로리 컬럼 활용)
def cal(x):
    if x >= 100:
        return 'No'
    else:
        return 'Yes'
df['먹어도 될까요'] = df['칼로리'].apply(cal)
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가 먹어도 될까요
# 0  아메리카노  4500   10   콜롬비아     NaN     Yes
# 1   카페라떼  5000  110  코스타리카  1000.0      No
# 2   카페모카  5500  250   과테말라  1000.0      No
# 3   카푸치노  5000  110   과테말라     NaN      No
# 4  에스프레소  4000   20  코스타리카     NaN     Yes
# 5    밀크티  5900  210  코스타리카     NaN      No
# 6     녹차  5300    0   대한민국     NaN     Yes
# 7   딴짓커피  2000   20  코스타리카     NaN     Yes

# %%
import pandas as pd
df = pd.DataFrame({'Name': {0: '쿼카', 1: '알파카', 2: '시바견'},
                   '수학': {0: 90, 1: 93, 2: 85},
                   '영어': {0: 92, 1: 84, 2: 86},
                   '국어': {0: 91, 1: 94, 2: 83},})
df
# Out:
#   Name  수학  영어  국어
# 0   쿼카  90  92  91
# 1  알파카  93  84  94
# 2  시바견  85  86  83

# %%
pd.melt(df, id_vars=['Name'])
# Out:
#   Name variable  value
# 0   쿼카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   쿼카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86
# 6   쿼카       국어     91
# 7  알파카       국어     94
# 8  시바견       국어     83

# %%
pd.melt(df, id_vars=['Name'], value_vars=['수학', '영어'])
# Out:
#   Name variable  value
# 0   쿼카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   쿼카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86

# %% [markdown]
# ### Section16. 그룹핑

# %%
df = pd.read_csv('cafe4.csv')
df.head()
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN

# %%
# 원두 기준, 평균
df.groupby(['원산지']).mean(numeric_only=True)
# Out:
#            가격    칼로리    이벤트가
# 원산지
# 과테말라   5250.0  180.0  1000.0
# 대한민국   5300.0    0.0     NaN
# 코스타리카  4225.0   90.0  1000.0
# 콜롬비아   4500.0   10.0     NaN

# %%
# 원두와 할인율 기준, 평균
df.groupby(['원산지', '칼로리']).mean(numeric_only=True)
# Out:
#                가격    이벤트가
# 원산지   칼로리
# 과테말라  110  5000.0     NaN
#       250  5500.0  1000.0
# 대한민국  0    5300.0     NaN
# 코스타리카 20   3000.0     NaN
#       110  5000.0  1000.0
#       210  5900.0     NaN
# 콜롬비아  10   4500.0     NaN

# %%
df.groupby(['원산지', '메뉴']).agg(['mean', 'max'])
# Out:
#                  가격          칼로리         이벤트가
#                mean   max   mean  max    mean     max
# 원산지   메뉴
# 과테말라  카페모카   5500.0  5500  250.0  250  1000.0  1000.0
#       카푸치노   5000.0  5000  110.0  110     NaN     NaN
# 대한민국  녹차     5300.0  5300    0.0    0     NaN     NaN
# 코스타리카 딴짓커피   2000.0  2000   20.0   20     NaN     NaN
#       밀크티    5900.0  5900  210.0  210     NaN     NaN
#       에스프레소  4000.0  4000   20.0   20     NaN     NaN
#       카페라떼   5000.0  5000  110.0  110  1000.0  1000.0
# 콜롬비아  아메리카노  4500.0  4500   10.0   10     NaN     NaN

# %%
# 1개 인덱스 형태로 리셋
df.groupby(['원산지', '칼로리']).mean(numeric_only=True).reset_index()
# Out:
#      원산지  칼로리      가격    이벤트가
# 0   과테말라  110  5000.0     NaN
# 1   과테말라  250  5500.0  1000.0
# 2   대한민국    0  5300.0     NaN
# 3  코스타리카   20  3000.0     NaN
# 4  코스타리카  110  5000.0  1000.0
# 5  코스타리카  210  5900.0     NaN
# 6   콜롬비아   10  4500.0     NaN

# %% [markdown]
# ### Section17. 시계열 데이터 (Datetime)

# %%
import pandas as pd
data = {
    'Date1': ['2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20'],
    'Date2': ['2024:02:17', '2024:02:18', '2024:02:19', '2024:02:20'],
    'Date3': ['24/02/17', '24/02/18', '24/02/19', '24/02/20'],
    'Date4': ['02/17/2024', '02/18/2024', '02/19/2024', '02/20/2024'],
    'Date5': ['17-Feb-2024', '18-Feb-2024', '19-Feb-2024', '20-Feb-2024'],
    'DateTime1': ['24-02-17 13:45:30', '24-02-18 14:55:45', '24-02-19 15:30:15', '24-02-20 16:10:50'],
    'DateTime2': ['2024-02-17 13-45-30', '2024-02-18 14-55-45', '2024-02-19 15-30-15', '2024-02-20 16-10-50'],
    'DateTime3': ['02/17/2024 01:45:30 PM', '02/18/2024 02:55:45 PM', '02/19/2024 03:30:15 AM', '02/20/2024 04:10:50 AM'],
    'DateTime4': ['17 Feb 2024 13:45:30', '18 Feb 2024 14:55:45', '19 Feb 2024 15:30:15', '20 Feb 2024 16:10:50']
}

df = pd.DataFrame(data)
df.to_csv("date_data.csv", index=False)
print(df.shape)
df
# Out:
# (4, 9)
#         Date1       Date2     Date3       Date4        Date5  \
# 0  2024-02-17  2024:02:17  24/02/17  02/17/2024  17-Feb-2024
# 1  2024-02-18  2024:02:18  24/02/18  02/18/2024  18-Feb-2024
# 2  2024-02-19  2024:02:19  24/02/19  02/19/2024  19-Feb-2024
# 3  2024-02-20  2024:02:20  24/02/20  02/20/2024  20-Feb-2024
#
#            DateTime1            DateTime2               DateTime3  \
# 0  24-02-17 13:45:30  2024-02-17 13-45-30  02/17/2024 01:45:30 PM
# 1  24-02-18 14:55:45  2024-02-18 14-55-45  02/18/2024 02:55:45 PM
# 2  24-02-19 15:30:15  2024-02-19 15-30-15  02/19/2024 03:30:15 AM
# 3  24-02-20 16:10:50  2024-02-20 16-10-50  02/20/2024 04:10:50 AM
#
#               DateTime4
# 0  17 Feb 2024 13:45:30
# 1  18 Feb 2024 14:55:45
# 2  19 Feb 2024 15:30:15
# 3  20 Feb 2024 16:10:50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date1      4 non-null      object
#  1   Date2      4 non-null      object
#  2   Date3      4 non-null      object
#  3   Date4      4 non-null      object
#  4   Date5      4 non-null      object
#  5   DateTime1  4 non-null      object
#  6   DateTime2  4 non-null      object
#  7   DateTime3  4 non-null      object
#  8   DateTime4  4 non-null      object
# dtypes: object(9)
# memory usage: 420.0+ bytes

# %%
df = pd.read_csv('date_data.csv')
df['Date1'] = pd.to_datetime(df['Date1'])
df['Date2'] = pd.to_datetime(df['Date2'], format='%Y:%m:%d')
df['Date3'] = pd.to_datetime(df['Date3'])
df['Date4'] = pd.to_datetime(df['Date4'])
df['Date5'] = pd.to_datetime(df['Date5'])
print(df['Date1'])
print(df['Date2'])
print(df['Date3'])
print(df['Date4'])
print(df['Date5'])
# Out:
# 0   2024-02-17
# 1   2024-02-18
# 2   2024-02-19
# 3   2024-02-20
# Name: Date1, dtype: datetime64[ns]
# 0   2024-02-17
# 1   2024-02-18
# 2   2024-02-19
# 3   2024-02-20
# Name: Date2, dtype: datetime64[ns]
# 0   2017-02-24
# 1   2018-02-24
# 2   2019-02-24
# 3   2020-02-24
# Name: Date3, dtype: datetime64[ns]
# 0   2024-02-17
# 1   2024-02-18
# 2   2024-02-19
# 3   2024-02-20
# Name: Date4, dtype: datetime64[ns]
# 0   2024-02-17
# 1   2024-02-18
# 2   2024-02-19
# 3   2024-02-20
# Name: Date5, dtype: datetime64[ns]
# <ipython-input-131-883b031dca2f>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date3'] = pd.to_datetime(df['Date3'])

# %%
df['DateTime1'] = pd.to_datetime(df['DateTime1'])
df['DateTime2'] = pd.to_datetime(df['DateTime2'], format='%Y-%m-%d %H-%M-%S')
df['DateTime3'] = pd.to_datetime(df['DateTime3'])
df['DateTime4'] = pd.to_datetime(df['DateTime4'])
print(df['DateTime1'])
print(df['DateTime2'])
print(df['DateTime3'])
print(df['DateTime4'])
# Out:
# 0   2017-02-24 13:45:30
# 1   2018-02-24 14:55:45
# 2   2019-02-24 15:30:15
# 3   2020-02-24 16:10:50
# Name: DateTime1, dtype: datetime64[ns]
# 0   2024-02-17 13:45:30
# 1   2024-02-18 14:55:45
# 2   2024-02-19 15:30:15
# 3   2024-02-20 16:10:50
# Name: DateTime2, dtype: datetime64[ns]
# 0   2024-02-17 13:45:30
# 1   2024-02-18 14:55:45
# 2   2024-02-19 03:30:15
# 3   2024-02-20 04:10:50
# Name: DateTime3, dtype: datetime64[ns]
# 0   2024-02-17 13:45:30
# 1   2024-02-18 14:55:45
# 2   2024-02-19 15:30:15
# 3   2024-02-20 16:10:50
# Name: DateTime4, dtype: datetime64[ns]
# <ipython-input-132-6e734fb57291>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime1'] = pd.to_datetime(df['DateTime1'])
# <ipython-input-132-6e734fb57291>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime3'] = pd.to_datetime(df['DateTime3'])

# %%
df = pd.read_csv("date_data.csv")
df['Date2'] = pd.to_datetime(df['Date2'], format='%Y:%m:%d')
df['Date3'] = pd.to_datetime(df['Date3'], format='%y/%m/%d')
df['DateTime1'] = pd.to_datetime(df['DateTime1'], format='%y-%m-%d %H:%M:%S')
df['DateTime2'] = pd.to_datetime(df['DateTime2'], format='%Y-%m-%d %H-%M-%S')
df[['Date2', 'Date3', 'DateTime1', 'DateTime2']]
# Out:
#        Date2      Date3           DateTime1           DateTime2
# 0 2024-02-17 2024-02-17 2024-02-17 13:45:30 2024-02-17 13:45:30
# 1 2024-02-18 2024-02-18 2024-02-18 14:55:45 2024-02-18 14:55:45
# 2 2024-02-19 2024-02-19 2024-02-19 15:30:15 2024-02-19 15:30:15
# 3 2024-02-20 2024-02-20 2024-02-20 16:10:50 2024-02-20 16:10:50

# %%
cols = ['Date2', 'Date3', 'DateTime1', 'DateTime2']
df[cols]
# Out:
#        Date2      Date3           DateTime1           DateTime2
# 0 2024-02-17 2024-02-17 2024-02-17 13:45:30 2024-02-17 13:45:30
# 1 2024-02-18 2024-02-18 2024-02-18 14:55:45 2024-02-18 14:55:45
# 2 2024-02-19 2024-02-19 2024-02-19 15:30:15 2024-02-19 15:30:15
# 3 2024-02-20 2024-02-20 2024-02-20 16:10:50 2024-02-20 16:10:50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date1      4 non-null      object
#  1   Date2      4 non-null      datetime64[ns]
#  2   Date3      4 non-null      datetime64[ns]
#  3   Date4      4 non-null      object
#  4   Date5      4 non-null      object
#  5   DateTime1  4 non-null      datetime64[ns]
#  6   DateTime2  4 non-null      datetime64[ns]
#  7   DateTime3  4 non-null      object
#  8   DateTime4  4 non-null      object
# dtypes: datetime64[ns](4), object(5)
# memory usage: 420.0+ bytes

# %%
df['year'] = df['DateTime1'].dt.year
df['month'] = df['DateTime1'].dt.month
df['day'] = df['DateTime1'].dt.day
df['hour'] = df['DateTime1'].dt.hour
df['minute'] = df['DateTime1'].dt.minute
df['second'] = df['DateTime1'].dt.second
df[['year', 'month', 'day', 'hour', 'minute', 'second']]
# Out:
#    year  month  day  hour  minute  second
# 0  2024      2   17    13      45      30
# 1  2024      2   18    14      55      45
# 2  2024      2   19    15      30      15
# 3  2024      2   20    16      10      50

# %%
df
# Out:
#         Date1      Date2      Date3       Date4        Date5  \
# 0  2024-02-17 2024-02-17 2024-02-17  02/17/2024  17-Feb-2024
# 1  2024-02-18 2024-02-18 2024-02-18  02/18/2024  18-Feb-2024
# 2  2024-02-19 2024-02-19 2024-02-19  02/19/2024  19-Feb-2024
# 3  2024-02-20 2024-02-20 2024-02-20  02/20/2024  20-Feb-2024
#
#             DateTime1           DateTime2               DateTime3  \
# 0 2024-02-17 13:45:30 2024-02-17 13:45:30  02/17/2024 01:45:30 PM
# 1 2024-02-18 14:55:45 2024-02-18 14:55:45  02/18/2024 02:55:45 PM
# 2 2024-02-19 15:30:15 2024-02-19 15:30:15  02/19/2024 03:30:15 AM
# 3 2024-02-20 16:10:50 2024-02-20 16:10:50  02/20/2024 04:10:50 AM
#
#               DateTime4  year  month  day  hour  minute  second
# 0  17 Feb 2024 13:45:30  2024      2   17    13      45      30
# 1  18 Feb 2024 14:55:45  2024      2   18    14      55      45
# 2  19 Feb 2024 15:30:15  2024      2   19    15      30      15
# 3  20 Feb 2024 16:10:50  2024      2   20    16      10      50

# %%
df['DateTime1'].dt.dayofweek
# Out:
# 0    5
# 1    6
# 2    0
# 3    1
# Name: DateTime1, dtype: int32

# %%
print(df['DateTime1'].dt.to_period('Y'))
print(df['DateTime1'].dt.to_period('Q'))
print(df['DateTime1'].dt.to_period('M'))
print(df['DateTime1'].dt.to_period('D'))
print(df['DateTime1'].dt.to_period('H'))
# Out:
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# Name: DateTime1, dtype: period[Y-DEC]
# 0    2024Q1
# 1    2024Q1
# 2    2024Q1
# 3    2024Q1
# Name: DateTime1, dtype: period[Q-DEC]
# 0    2024-02
# 1    2024-02
# 2    2024-02
# 3    2024-02
# Name: DateTime1, dtype: period[M]
# 0    2024-02-17
# 1    2024-02-18
# 2    2024-02-19
# 3    2024-02-20
# Name: DateTime1, dtype: period[D]
# 0    2024-02-17 13:00
# 1    2024-02-18 14:00
# 2    2024-02-19 15:00
# 3    2024-02-20 16:00
# Name: DateTime1, dtype: period[h]
# <ipython-input-139-8d650335b6b3>:5: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   print(df['DateTime1'].dt.to_period('H'))

# %% [markdown]
# ### Section18. 시계열 데이터 (Timedelta)

# %%
df = pd.read_csv('date_data.csv', usecols=['DateTime4'], parse_dates=['DateTime4'])
df
# Out:
#             DateTime4
# 0 2024-02-17 13:45:30
# 1 2024-02-18 14:55:45
# 2 2024-02-19 15:30:15
# 3 2024-02-20 16:10:50

# %%
day = pd.Timedelta(days=99)
df['100day'] = df['DateTime4'] + day
df
# Out:
#             DateTime4              100day
# 0 2024-02-17 13:45:30 2024-05-26 13:45:30
# 1 2024-02-18 14:55:45 2024-05-27 14:55:45
# 2 2024-02-19 15:30:15 2024-05-28 15:30:15
# 3 2024-02-20 16:10:50 2024-05-29 16:10:50

# %%
hour = pd.Timedelta(hours=100)
df['100hour'] = df['DateTime4'] + hour
df
# Out:
#             DateTime4              100day             100hour
# 0 2024-02-17 13:45:30 2024-05-26 13:45:30 2024-02-21 17:45:30
# 1 2024-02-18 14:55:45 2024-05-27 14:55:45 2024-02-22 18:55:45
# 2 2024-02-19 15:30:15 2024-05-28 15:30:15 2024-02-23 19:30:15
# 3 2024-02-20 16:10:50 2024-05-29 16:10:50 2024-02-24 20:10:50

# %%
difference = pd.Timedelta(weeks=7, days=7, hours=7, minutes=7, seconds=7)
df['difference'] = df['DateTime4'] - difference
df
# Out:
#             DateTime4              100day             100hour  \
# 0 2024-02-17 13:45:30 2024-05-26 13:45:30 2024-02-21 17:45:30
# 1 2024-02-18 14:55:45 2024-05-27 14:55:45 2024-02-22 18:55:45
# 2 2024-02-19 15:30:15 2024-05-28 15:30:15 2024-02-23 19:30:15
# 3 2024-02-20 16:10:50 2024-05-29 16:10:50 2024-02-24 20:10:50
#
#            difference
# 0 2023-12-23 06:38:23
# 1 2023-12-24 07:48:38
# 2 2023-12-25 08:23:08
# 3 2023-12-26 09:03:43

# %%
diff = df['100hour'] - df['difference']
diff
# Out:
# 0   60 days 11:07:07
# 1   60 days 11:07:07
# 2   60 days 11:07:07
# 3   60 days 11:07:07
# dtype: timedelta64[ns]

# %%
print(diff.dt.total_seconds()) # 초
print(diff.dt.total_seconds()/60) # 분
print(diff.dt.total_seconds()/60/60) # 시간
print(diff.dt.total_seconds()/60/60/24) # 일
# Out:
# 0    5224027.0
# 1    5224027.0
# 2    5224027.0
# 3    5224027.0
# dtype: float64
# 0    87067.116667
# 1    87067.116667
# 2    87067.116667
# 3    87067.116667
# dtype: float64
# 0    1451.118611
# 1    1451.118611
# 2    1451.118611
# 3    1451.118611
# dtype: float64
# 0    60.463275
# 1    60.463275
# 2    60.463275
# 3    60.463275
# dtype: float64

# %%
print(diff.dt.days)
print(diff.dt.seconds)
# Out:
# 0    60
# 1    60
# 2    60
# 3    60
# dtype: int64
# 0    40027
# 1    40027
# 2    40027
# 3    40027
# dtype: int32

# %%
min = 5.41
print(int(min), "분")
print(0.41*60, "초")
# Out:
# 5 분
# 24.599999999999998 초

# %%
print(round(diff.dt.total_seconds()/60))
# Out:
# 0    87067.0
# 1    87067.0
# 2    87067.0
# 3    87067.0
# dtype: float64

# %% [markdown]
# ### Section19. 데이터 합치기

# %%
import pandas as pd

# 에피타이저 메뉴
appetizer = pd.DataFrame({
    'Menu': ['Salad', 'Soup', 'Bread'],
    'Price': [5000, 3000, 2000]
})

# 메인 메뉴
main = pd.DataFrame({
    'Menu': ['Steak', 'Pasta', 'Chicken'],
    'Price': [15000, 12000, 10000]
})
print(appetizer)
print(main)
# Out:
#     Menu  Price
# 0  Salad   5000
# 1   Soup   3000
# 2  Bread   2000
#       Menu  Price
# 0    Steak  15000
# 1    Pasta  12000
# 2  Chicken  10000

# %%
# 두 메뉴를 수직으로 연결
full_menu = pd.concat([appetizer, main], ignore_index=True)
full_menu
# Out:
#       Menu  Price
# 0    Salad   5000
# 1     Soup   3000
# 2    Bread   2000
# 3    Steak  15000
# 4    Pasta  12000
# 5  Chicken  10000

# %%
# 두 메뉴를 좌우로 연결
full_menu = pd.concat([appetizer, main], axis=1)
full_menu
# Out:
#     Menu  Price     Menu  Price
# 0  Salad   5000    Steak  15000
# 1   Soup   3000    Pasta  12000
# 2  Bread   2000  Chicken  10000

# %%
# 메뉴와 가격
price = pd.DataFrame({
    'Menu': ['Salad', 'Soup', 'Steak', 'Pasta'],
    'Price': [5000, 3000, 15000, 12000]
})

# 메뉴와 칼로리
cal = pd.DataFrame({
    'Menu': ['Soup', 'Steak', 'Pasta','Salad'],
    'Calories': [100, 500, 400, 150]
})

# 두 데이터프레임을 'Menu'를 기준으로 병합
menu_info = pd.merge(price, cal, on='Menu')
menu_info
# Out:
#     Menu  Price  Calories
# 0  Salad   5000       150
# 1   Soup   3000       100
# 2  Steak  15000       500
# 3  Pasta  12000       400

# %% [markdown]
# ### Section20.Quiz

# %%
# 데이터 불러오기
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "메뉴":['아메리카노', '카페라떼', '에스프레소', '카페모카', '바닐라라떼'],
    "가격":[4500, 5000, 4000, 5900, 5300],
    "칼로리":[10, 110, np.NaN, 210, np.NaN],
    "원산지":['과테말라','브라질','과테말라', np.NaN, np.NaN]
})
print(df.shape)
df
# Out:
# (5, 4)
#       메뉴    가격    칼로리   원산지
# 0  아메리카노  4500   10.0  과테말라
# 1   카페라떼  5000  110.0   브라질
# 2  에스프레소  4000    NaN  과테말라
# 3   카페모카  5900  210.0   NaN
# 4  바닐라라떼  5300    NaN   NaN

# %% [markdown]
# #### 문1) '칼로리' 컬럼 결측치는 칼로리 데이터 중 최솟값으로 결측치를 채우시오.

# %%
min_cal = df['칼로리'].min()
df['칼로리'] = df['칼로리'].fillna(min_cal)
df
# Out:
#       메뉴    가격    칼로리   원산지
# 0  아메리카노  4500   10.0  과테말라
# 1   카페라떼  5000  110.0   브라질
# 2  에스프레소  4000   10.0  과테말라
# 3   카페모카  5900  210.0   NaN
# 4  바닐라라떼  5300   10.0   NaN

# %% [markdown]
# #### 문2) '원산지' 컬럼 결측치는 원두 데이터 중 최빈값으로 결측치를 채우시오.

# %%
f = df['원산지'].mode()[0]
df['원산지'] = df['원산지'].fillna(f)
df
# Out:
#       메뉴    가격    칼로리   원산지
# 0  아메리카노  4500   10.0  과테말라
# 1   카페라떼  5000  110.0   브라질
# 2  에스프레소  4000   10.0  과테말라
# 3   카페모카  5900  210.0  과테말라
# 4  바닐라라떼  5300   10.0  과테말라

# %% [markdown]
# #### 문3) 가격이 5000 이상인 데이터의 수를 구하시오.

# %%
cond = df['가격'] >= 5000
len(df[cond])
# Out:
# 3

# %% [markdown]
# #### 문4) '이벤트가' 컬럼을 만들고 기존 가격에서 50% 할인된 가격을 채우시오.

# %%
df['이벤트가'] = df['가격'] * 0.5
df
# Out:
#       메뉴    가격    칼로리   원산지    이벤트가
# 0  아메리카노  4500   10.0  과테말라  2250.0
# 1   카페라떼  5000  110.0   브라질  2500.0
# 2  에스프레소  4000   10.0  과테말라  2000.0
# 3   카페모카  5900  210.0  과테말라  2950.0
# 4  바닐라라떼  5300   10.0  과테말라  2650.0

# %% [markdown]
# #### 문5) '칼로리' 컬럼을 삭제하시오.

# %%
df = df.drop('칼로리', axis=1)
df
# Out:
#       메뉴    가격   원산지    이벤트가
# 0  아메리카노  4500  과테말라  2250.0
# 1   카페라떼  5000   브라질  2500.0
# 2  에스프레소  4000  과테말라  2000.0
# 3   카페모카  5900  과테말라  2950.0
# 4  바닐라라떼  5300  과테말라  2650.0

# %% [markdown]
# #### 문6) 앞에서부터 3개의 데이터만 선택하시오(loc 활용)

# %%
df.loc[:2]
# Out:
#       메뉴    가격   원산지    이벤트가
# 0  아메리카노  4500  과테말라  2250.0
# 1   카페라떼  5000   브라질  2500.0
# 2  에스프레소  4000  과테말라  2000.0

# %% [markdown]
# #### 문7) 앞에서부터 3개의 데이터만 선택하시오(iloc 활용)

# %%
df = df.iloc[:3]
df
# Out:
#       메뉴    가격   원산지    이벤트가
# 0  아메리카노  4500  과테말라  2250.0
# 1   카페라떼  5000   브라질  2500.0
# 2  에스프레소  4000  과테말라  2000.0

# %% [markdown]
# #### 문8) 주어진 데이터(df)에서 아래 값을 loc을 활용하여 데이터 프레임으로 출력하시오.

# %% [markdown]
# ##### (카페라떼 5000), (에스프레소 4000)

# %%
# loc
df.loc[1:2, :'가격']
# Out:
#       메뉴    가격
# 1   카페라떼  5000
# 2  에스프레소  4000

# %% [markdown]
# #### 문9) 주어진 데이터(df)에서 아래 값을 iloc을 활용하여 데이터 프레임으로 출력하시오.

# %% [markdown]
# ##### (카페라떼 5000), (에스프레소 4000)

# %%
df.iloc[1:3, :2]
# Out:
#       메뉴    가격
# 1   카페라떼  5000
# 2  에스프레소  4000

# %% [markdown]
# #### 문10) 메뉴 중 가격이 가장 비싼 순으로 정렬하여 상위 3개 값을 구하시오.

# %%
df = df.sort_values(by='가격', ascending=False)
print(df.shape)
df
# Out:
# (3, 4)
#       메뉴    가격   원산지    이벤트가
# 1   카페라떼  5000   브라질  2500.0
# 0  아메리카노  4500  과테말라  2250.0
# 2  에스프레소  4000  과테말라  2000.0

# %% [markdown]
# # ch3_ex_type1

# %% [markdown]
# ## 여러 유형들

# %% [markdown]
# ### Section1.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")
print(df.shape)
df.info()
# Out:
# (120, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          120 non-null    object
#  1   age         120 non-null    float64
#  2   city        120 non-null    object
#  3   f1          89 non-null     float64
#  4   f2          120 non-null    int64
#  5   f3          91 non-null     object
#  6   f4          120 non-null    object
#  7   f5          120 non-null    float64
#  8   subscribed  120 non-null    object
#  9   views       116 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 9.5+ KB

# %%
df.head()
# Out:
#      id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0  id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2024-07-16  6820.0
# 1  id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2024-05-12  2534.0
# 2  id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2024-03-16  7312.0
# 3  id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2024-07-21   493.0
# 4  id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2024-03-07  1338.0

# %%
# 0 제외
cond = df['f5'] != 0
df = df[cond]

# 'views' 컬럼 결측치 최소값으로 채우기
min = df['views'].min(skipna=True)
df = df.assign(views=df['views'].fillna(min))

# 'views' 컬럼 중앙값 계산
print(int(df['views'].median()))
# Out:
# 5924

# %% [markdown]
# ### Section2.

# %%
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

print(df.shape)
df.info()
# Out:
# (120, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          120 non-null    object
#  1   age         120 non-null    float64
#  2   city        120 non-null    object
#  3   f1          89 non-null     float64
#  4   f2          120 non-null    int64
#  5   f3          91 non-null     object
#  6   f4          120 non-null    object
#  7   f5          120 non-null    float64
#  8   subscribed  120 non-null    object
#  9   views       116 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 9.5+ KB

# %%
df.head()
# Out:
#      id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0  id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2024-07-16  6820.0
# 1  id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2024-05-12  2534.0
# 2  id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2024-03-16  7312.0
# 3  id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2024-07-21   493.0
# 4  id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2024-03-07  1338.0

# %%
# subscribed 종류 중 가장 많은 날짜 구하기
df = df['subscribed'].value_counts()
print(df.index[0])

# 일(day)값을 찾고, 정수형으로 변경
int(df.index[0][-2:])
# Out:
# 2025-02-17
# 17

# %% [markdown]
# ### Section3.

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치 제거
df = df.dropna()

# 새로운 컬럼 계산
df['new'] = df['views'] / df['f1']

# 내림차순 정렬
df = df.sort_values(by='new', ascending=False)

# age 값 찾아서 출력
int(df.iloc[0,1])
# Out:
# 22

# %% [markdown]
# ### Section4.

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          120 non-null    object
#  1   age         120 non-null    float64
#  2   city        120 non-null    object
#  3   f1          89 non-null     float64
#  4   f2          120 non-null    int64
#  5   f3          91 non-null     object
#  6   f4          120 non-null    object
#  7   f5          120 non-null    float64
#  8   subscribed  120 non-null    object
#  9   views       116 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 9.5+ KB

# %%
# 결측 데이터 0으로 대체
df['views'].fillna(0, inplace=True)

# 내림차순 정렬
df = df.sort_values(by='views', ascending=False)

# views 상위 10개 데이터에 최소값 대입
views_min = df.iloc[:10]['views'].min()
df.iloc[:10, -1] = views_min

# views 컬럼의 합
print(int(df['views'].sum()))
# Out:
# 652812
# <ipython-input-186-6dc3357d34f3>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['views'].fillna(0, inplace=True)

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측 데이터 0으로 대체
df['views'].fillna(0, inplace=True)

# views 컬럼에서 10번째로 큰 값을 구합니다.
value = df['views'].nlargest(10).iloc[-1]

# views 컬럼에서 가장 큰 10개의 값을 10번째로 큰 값으로 대체
df.loc[df['views'] > value, 'views'] = value

# views 컬럼의 합
print(int(df['views'].sum()))
# Out:
# 652812
# <ipython-input-187-fece6007a668>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['views'].fillna(0, inplace=True)

# %% [markdown]
# ### Section5

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")
df.head()
# Out:
#      id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0  id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2024-07-16  6820.0
# 1  id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2024-05-12  2534.0
# 2  id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2024-03-16  7312.0
# 3  id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2024-07-21   493.0
# 4  id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2024-03-07  1338.0

# %%
print(df.shape)
df.info()
# Out:
# (120, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          120 non-null    object
#  1   age         120 non-null    float64
#  2   city        120 non-null    object
#  3   f1          89 non-null     float64
#  4   f2          120 non-null    int64
#  5   f3          91 non-null     object
#  6   f4          120 non-null    object
#  7   f5          120 non-null    float64
#  8   subscribed  120 non-null    object
#  9   views       116 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 9.5+ KB

# %%
df['f4'].value_counts()
# Out:
# f4
# ISFP    14
# ESTJ    13
# ESTP    11
# ISFJ    10
# ENTP    10
# INFP     9
# INTP     9
# ESFJ     8
# ENFJ     6
# ENFP     6
# ESFP     5
# ENTJ     5
# INFJ     4
# ISTP     4
# INTJ     4
# ISTJ     2
# Name: count, dtype: int64

# %%
# f4 컬럼에서 뒤에 2개 값 슬라이싱
df['new'] = df['f4'].str[2:4]

# FJ인 데이터 찾기
cond = df['new'] == 'FJ'
df = df[cond]

# f2 평균 구하기
print(round(df['f2'].mean(), 2))
# Out:
# 0.61
